# %% [markdown]
# # HEATHOTSAUCE.COM SCRAPE
#
# https://heathotsauce.com

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
# scrape all 19 pages to get names and urls

names = []
urls = []

# go to each page (print progress)
for i in range(1, 19):
    url = 'https://heathotsauce.com/collections/all?page=' + str(i)
    page = requests.get(url)
    print i, page
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #in each page, scrape the names
    for j in soup.findAll('span', class_='title product-name-custom'):
        names.append(j.get_text())
    for k in soup.findAll(itemprop = 'url'):
        urls.append(k.get('href'))
# Out:
# 1 <Response [200]>
# 2 <Response [200]>
# 3 <Response [200]>
# 4 <Response [200]>
# 5 <Response [200]>
# 6 <Response [200]>
# 7 <Response [200]>
# 8 <Response [200]>
# 9 <Response [200]>
# 10 <Response [200]>
# 11 <Response [200]>
# 12 <Response [200]>
# 13 <Response [200]>
# 14 <Response [200]>
# 15 <Response [200]>
# 16 <Response [200]>
# 17 <Response [200]>
# 18 <Response [200]>

# %%
#combine names and urls into a df
names_urls = pd.DataFrame({'names':names, 'urls':urls})

# add url to start of urls
names_urls['urls'] = names_urls['urls'].apply(lambda x: 'https://heathotsauce.com' + str(x))

# %%
names_urls
# Out:
#                                               names  \
# 0                       Secret Aardvark Serrabanero
# 1                  Heartbeat Hot Sauce Red Habanero
# 2                            Howler Monkey Original
# 3                                        Pueblo Red
# 4                                Pineapple Dreamin'
# 5                                  Reaper's Revenge
# 6                     CaJohn's Classic Ghost Pepper
# 7                                   Death By Kraken
# 8                    Palo Alto Firefighters Packets
# 9                                   Secret Aardvark
# 10                           Whole Ghost Pepper Pod
# 11                           Dirty Dick's Hot Sauce
# 12                        Yellowbird Habanero Sauce
# 13                                 7o8 7 Pot Citrus
# 14                 Scotch Bonnet & Ginger Hot Sauce
# 15                                 Orifice Reducers
# 16     Palo Alto Firefighters Habanero Pepper Sauce
# 17   Year of the Dog Thai Chile Pineapple Hot Sauce
# 18                                     Purple Hippo
# 19                      Humble House Ancho & Morita
# 20                        I Heart Hot Sauce Sticker
# 21                                Cutino's Chipotle
# 22         Bravado Spice Ghost Pepper and Blueberry
# 23                               Char Man Caribbean
# 24        Palo Alto Firefighters Ghost Pepper Sauce
# 25                       Marie Sharp's Hot Habanero
# 26                                    Dia Del Perro
# 27                    Yellowbird Ghost Pepper Sauce
# 28                                 Formosa Chipotle
# 29                      The Bronx Greenmarket Green
# ..                                              ...
# 594                  Redditor-Made Hot Sauce 6 Pack
# 595                   Bill Moore's Super Hot 4-Pack
# 596                Yellowbird Habanero 1 Gallon Jug
# 597                        Ultimate Mellow Gift Set
# 598    Ultimate Superhot & Super Flavorful Gift Set
# 599                                 Picante Pumpkin
# 600                               Don Chingon Arbol
# 601                    Taco 'n' Burrito Sauce No. 6
# 602                         Nando's Peri-Peri Sauce
# 603                          Cranberry Red Jalapeno
# 604                           Chilebrown's Gift Set
# 605                       Walkerswood Scotch Bonnet
# 606                  Nando's Garlic Peri-Peri Sauce
# 607                 Hot Squeeze Sweet Heat Chipotle
# 608                    Spicy Banana Saltwater Taffy
# 609        Blueberry Hell Special Reserve Hot Sauce
# 610                                 Grapes of Wrath
# 611            Frankie V's Habanero Infused Vinegar
# 612                                Mangoes! Bumbye!
# 613                                     Penance Due
# 614                      9CoH ORIGINAL Chile Powder
# 615                         TastingTheHeat Gift Set
# 616              Chocolate Orange Dessert Hot Sauce
# 617                Heartbreaking Dawns Mauvais Sang
# 618                                  Burn Baby Burn
# 619                               Frankie V's Fiery
# 620                         Wasabi Green Thai Chile
# 621                            Blair's 2 AM Reserve
# 622                                    Cosmic Peach
# 623                        9CoH SMOKED Chile Powder
#
#                                                   urls
# 0    https://heathotsauce.com/collections/all/produ...
# 1    https://heathotsauce.com/collections/all/produ...
# 2    https://heathotsauce.com/collections/all/produ...
# 3    https://heathotsauce.com/collections/all/produ...
# 4    https://heathotsauce.com/collections/all/produ...
# 5    https://heathotsauce.com/collections/all/produ...
# 6    https://heathotsauce.com/collections/all/produ...
# 7    https://heathotsauce.com/collections/all/produ...
# 8    https://heathotsauce.com/collections/all/produ...
# 9    https://heathotsauce.com/collections/all/produ...
# 10   https://heathotsauce.com/collections/all/produ...
# 11   https://heathotsauce.com/collections/all/produ...
# 12   https://heathotsauce.com/collections/all/produ...
# 13   https://heathotsauce.com/collections/all/produ...
# 14   https://heathotsauce.com/collections/all/produ...
# 15   https://heathotsauce.com/collections/all/produ...
# 16   https://heathotsauce.com/collections/all/produ...
# 17   https://heathotsauce.com/collections/all/produ...
# 18   https://heathotsauce.com/collections/all/produ...
# 19   https://heathotsauce.com/collections/all/produ...
# 20   https://heathotsauce.com/collections/all/produ...
# 21   https://heathotsauce.com/collections/all/produ...
# 22   https://heathotsauce.com/collections/all/produ...
# 23   https://heathotsauce.com/collections/all/produ...
# 24   https://heathotsauce.com/collections/all/produ...
# 25   https://heathotsauce.com/collections/all/produ...
# 26   https://heathotsauce.com/collections/all/produ...
# 27   https://heathotsauce.com/collections/all/produ...
# 28   https://heathotsauce.com/collections/all/produ...
# 29   https://heathotsauce.com/collections/all/produ...
# ..                                                 ...
# 594  https://heathotsauce.com/collections/all/produ...
# 595  https://heathotsauce.com/collections/all/produ...
# 596  https://heathotsauce.com/collections/all/produ...
# 597  https://heathotsauce.com/collections/all/produ...
# 598  https://heathotsauce.com/collections/all/produ...
# 599  https://heathotsauce.com/collections/all/produ...
# 600  https://heathotsauce.com/collections/all/produ...
# 601  https://heathotsauce.com/collections/all/produ...
# 602  https://heathotsauce.com/collections/all/produ...
# 603  https://heathotsauce.com/collections/all/produ...
# 604  https://heathotsauce.com/collections/all/produ...
# 605  https://heathotsauce.com/collections/all/produ...
# 606  https://heathotsauce.com/collections/all/produ...
# 607  https://heathotsauce.com/collections/all/produ...
# 608  https://heathotsauce.com/collections/all/produ...
# 609  https://heathotsauce.com/collections/all/produ...
# 610  https://heathotsauce.com/collections/all/produ...
# 611  https://heathotsauce.com/collections/all/produ...
# 612  https://heathotsauce.com/collections/all/produ...
# 613  https://heathotsauce.com/collections/all/produ...
# 614  https://heathotsauce.com/collections/all/produ...
# 615  https://heathotsauce.com/collections/all/produ...
# 616  https://heathotsauce.com/collections/all/produ...
# 617  https://heathotsauce.com/collections/all/produ...
# 618  https://heathotsauce.com/collections/all/produ...
# 619  https://heathotsauce.com/collections/all/produ...
# 620  https://heathotsauce.com/collections/all/produ...
# 621  https://heathotsauce.com/collections/all/produ...
# 622  https://heathotsauce.com/collections/all/produ...
# 623  https://heathotsauce.com/collections/all/produ...
#
# [624 rows x 2 columns]

# %%
## Go to each unique url, grab name, price, manufacturer, description

## NOTE: I requested too many timesand was timed out. 
## Do this in batches, save as different df, then concat together

name = []
mfc = []
price = []
desc = []
urls = []

for n, url in enumerate(names_urls['urls'][:21]):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
#     name
    try:
        name.append(soup.find('h1', class_='product_name').get_text())
    except:
        name.append('')
#     manufacturer
    try:
        mfc.append(soup.find('p', class_='vendor').get_text())
    except:
        mfc.append('')
#     price
    try:
        price.append(soup.find('span', class_='money').get_text())
    except:
        price.append('')
#     description
    try:
        desc.append(soup.find('div', class_='description').get_text())
    except:
        desc.append('')
#     url
    try:
        urls.append(url)
    except:
        urls.append('')
    
#     print progress, if response != 200, stop kernel. you have been timed out
    print n, page

df_1 = pd.DataFrame({'names':name,
                   'mfc':mfc,
                   'price':price,
                   'desc':desc,
                   'url':urls})
# Out:
# 0 <Response [200]>
# 1 <Response [200]>
# 2 <Response [200]>
# 3 <Response [200]>
# 4 <Response [200]>
# 5 <Response [200]>
# 6 <Response [200]>
# 7 <Response [200]>
# 8 <Response [200]>
# 9 <Response [200]>
# 10 <Response [200]>
# 11 <Response [200]>
# 12 <Response [200]>
# 13 <Response [200]>
# 14 <Response [200]>
# 15 <Response [200]>
# 16 <Response [200]>
# 17 <Response [200]>
# 18 <Response [200]>
# 19 <Response [200]>
# 20 <Response [200]>

# %%
df_1
# Out:
#                                                  desc  \
# 0   \nSecret Aardvark's new Serrabanero is a tasty...
# 1   \nMade in Thunder Bay Ontario, this small batc...
# 2   \nA classic Panamanian-style sauce (also known...
# 3   \n\nA thick and hearty red pepper sauce made w...
# 4   \nA flavorful pineapple sauce, made with ginge...
# 5   \nA fiery combination of tomatoes, carrots, an...
# 6   \nA truly classic blend of ghost chile peppers...
# 7   \n﻿Monroy's Death By Kraken is an extra hot bl...
# 8   \nThese to-go packets of Palo Alto Firefighter...
# 9   \nSecret Aardvark is a flavorful sauce made in...
# 10   \nA free sample of 1 whole dried ghost pepper!\n
# 11  \nThis bold, sweet and spicy sauce combines an...
# 12  \nAn absolutely delicious sriracha style sauce...
# 13  \n7o8 is one of the most flavorful superhot sa...
# 14  \nQueen Majesty Scotch Bonnet & Ginger Hot Sau...
# 15  \nEver get a sauce that pours out to quickly, ...
# 16  \n\nMade by an actual retired firefighter from...
# 17  \nAn impossibly delicious Thai chile pineapple...
# 18  \nA entirely unique sauce made with tangy Pric...
# 19  \nA smooth blend of Morita chiles, ripened Anc...
# 20
#
#                                mfc  \
# 0   \nSecret Aardvark Trading Co\n
# 1      \nHeartbeat Hot Sauce Co.\n
# 2                \nHowler Monkey\n
# 3                   \nPexPeppers\n
# 4                   \nJak Jeckel\n
# 5               \nHotter Than El\n
# 6                      \nCaJohns\n
# 7           \nMonroy's Hot Sauce\n
# 8       \nPalo Alto Firefighters\n
# 9   \nSecret Aardvark Trading Co\n
# 10         \nHeat Hot Sauce Shop\n
# 11                \nDirty Dick's\n
# 12                  \nYellowbird\n
# 13                    \nBigfat's\n
# 14     \nQueen Majesty Hot Sauce\n
# 15                    \nFreebies\n
# 16      \nPalo Alto Firefighters\n
# 17         \nLucky Dog Hot Sauce\n
# 18       \nAngry Goat Pepper Co.\n
# 19          \nHumble House Foods\n
# 20                        \nHeat\n
#
#                                                 names    price  \
# 0                     Secret Aardvark Serrabanero       $ 6.99
# 1                Heartbeat Hot Sauce Red Habanero      $ 11.75
# 2                          Howler Monkey Original       $ 6.99
# 3                                      Pueblo Red       $ 7.99
# 4                              Pineapple Dreamin'       $ 8.99
# 5                                Reaper's Revenge       $ 8.99
# 6                   CaJohn's Classic Ghost Pepper       $ 7.99
# 7                                 Death By Kraken       $ 9.99
# 8                  Palo Alto Firefighters Packets       $ 2.00
# 9                                 Secret Aardvark       $ 5.99
# 10                         Whole Ghost Pepper Pod       $ 0.50
# 11                         Dirty Dick's Hot Sauce       $ 7.99
# 12                      Yellowbird Habanero Sauce       $ 5.99
# 13                               7o8 7 Pot Citrus       $ 6.49
# 14               Scotch Bonnet & Ginger Hot Sauce       $ 9.99
# 15                               Orifice Reducers       $ 0.50
# 16   Palo Alto Firefighters Habanero Pepper Sauce       $ 6.99
# 17   Year of the Dog Thai Chile Pineapple Hot Sauc...   $ 9.99
# 18                                   Purple Hippo       $ 8.99
# 19                    Humble House Ancho & Morita       $ 9.99
# 20                      I Heart Hot Sauce Sticker       $ 0.50
#
#                                                   url
# 0   https://heathotsauce.com/collections/all/produ...
# 1   https://heathotsauce.com/collections/all/produ...
# 2   https://heathotsauce.com/collections/all/produ...
# 3   https://heathotsauce.com/collections/all/produ...
# 4   https://heathotsauce.com/collections/all/produ...
# 5   https://heathotsauce.com/collections/all/produ...
# 6   https://heathotsauce.com/collections/all/produ...
# 7   https://heathotsauce.com/collections/all/produ...
# 8   https://heathotsauce.com/collections/all/produ...
# 9   https://heathotsauce.com/collections/all/produ...
# 10  https://heathotsauce.com/collections/all/produ...
# 11  https://heathotsauce.com/collections/all/produ...
# 12  https://heathotsauce.com/collections/all/produ...
# 13  https://heathotsauce.com/collections/all/produ...
# 14  https://heathotsauce.com/collections/all/produ...
# 15  https://heathotsauce.com/collections/all/produ...
# 16  https://heathotsauce.com/collections/all/produ...
# 17  https://heathotsauce.com/collections/all/produ...
# 18  https://heathotsauce.com/collections/all/produ...
# 19  https://heathotsauce.com/collections/all/produ...
# 20  https://heathotsauce.com/collections/all/produ...

# %%
# combine all df batches. strip manufacturers of \n
full_df = pd.concat([df1, df2, df3])
full_df['mfc'] = full_df['mfc'].apply(lambda x: x.strip())

# remove gift sets and empty rows
full_df = full_df[full_df['mfc'] != 'Gift Set']
full_df = full_df[full_df['desc'] != '']
full_df.reset_index(inplace=True, drop=True)

# save df as csv
full_df.to_csv('hot_sauces.csv', encoding='utf-8', index=False)
